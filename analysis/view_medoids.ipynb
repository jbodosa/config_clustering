# %%
# Imports
import numpy as np
import MDAnalysis as mda
import os
from glob import glob
import nglview as nv

# %%
# !pwd
# Out:
# /scratch/zt1/project/energybio/user/jbodosa/data/beryllium/charmm_be/be_namd/openmm_files/config_clustering/analysis

# %%
medoids=glob("medoid*.pdb")

# %%
u = mda.Universe(medoids[-1])
# Out:
# /scratch/zt1/project/energybio/user/jbodosa/data/exec/miniconda3/envs/py3_mda/lib/python3.12/site-packages/MDAnalysis/topology/PDBParser.py:331: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using MDAnalysis.topology.guessers.
#   warnings.warn("Element information is missing, elements attribute "
# /scratch/zt1/project/energybio/user/jbodosa/data/exec/miniconda3/envs/py3_mda/lib/python3.12/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types: BE
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))
# /scratch/zt1/project/energybio/user/jbodosa/data/exec/miniconda3/envs/py3_mda/lib/python3.12/site-packages/MDAnalysis/coordinates/PDB.py:453: UserWarning: 1 A^3 CRYST1 record, this is usually a placeholder. Unit cell dimensions will be set to None.
#   warnings.warn("1 A^3 CRYST1 record,"

# %%
window = nv.show_mdanalysis(u)
window.add_representation(repr_type='licorice', selection='resname TIP', opacity='0.5')
window
# Out:
# NGLWidget()
